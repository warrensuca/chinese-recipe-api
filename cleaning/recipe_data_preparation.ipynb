# %% [markdown]
# <a href="https://colab.research.google.com/github/warrensuca/chinese-recipe-api/blob/main/warrensuca/chinese-recipe-api/cleaning/recipe_data_preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Combine, Clean, and Normalize the Recipe Data
# The point of the scraping is to have recipe data useful for k-means clustering and a kNN model. Therefore, the data should be combined, cleaned, and normalized.
#
# Clean by removing duplicates and expanding individual nutrition facts into their own columns
#
# Normalize by looking at the distributions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ast
from sklearn.preprocessing import PowerTransformer
print("setup complete")
# Out:
# setup complete

# %% [markdown]
# #Data Cleaning

# %% [markdown]
# ##Woks of Life cleaning
# We are looking to
# - remove duplicates
# - parse and expand nutritional info into individual columns

# %%
df_wol = pd.read_csv("woks_of_life_recipes.csv")
print("original shape:", df_wol.shape)


df_wol = df_wol[~(df_wol == "[]").any(axis=1)]

df_wol = df_wol[df_wol['Nutrition_Facts'].str.len() != 5] # debug trial and error: print(x, len(x)) -> ['4'] 5
print("new shape:", df_wol.shape)

def format_serving(stringified_list):

    nutrition_list = ast.literal_eval(stringified_list)

    end = "serving" if nutrition_list[0] == 1 else "servings"

    nutrition_list[0] = f"Serving: {nutrition_list[0]}{end}"


    return str(nutrition_list)


df_wol['Nutrition_Facts'] = df_wol['Nutrition_Facts'].map(format_serving)

nutrition_columns = ['Calories', 'Carbohydrates', 'Protein', 'Fat', 'Saturated Fat', 'Sodium', 'Sugar']
valid_nutrients = set(nutrition_columns)

suffix_to_value = {
    'kcal': 1,
    'mg' : 1/1000,
    'g' : 1,
    'kg' : 1000
}

all_nutrition_data = []
for nutrition_string in df_wol['Nutrition_Facts']:

  nutrition_list = ast.literal_eval(nutrition_string)

  temp_dict = {col: 0 for col in nutrition_columns}


  for nutrient_profile in nutrition_list:


      if ':' not in nutrient_profile:
          continue

      name, value_str = nutrient_profile.split(':', 1)
      nutrient_name = name.strip()

      if nutrient_name in valid_nutrients:
          num = ""
          suffix = ""

          for char in value_str:
              if char.isdigit() or char == '.':
                  num += char
              elif char == '(':
                  break
              else:
                  suffix += char

          if num: # ensure we actually found a number
              temp_dict[nutrient_name] += float(num) * suffix_to_value[suffix.strip()]

  all_nutrition_data.append(temp_dict)
df_wol['Nutrition_Facts'] = df_wol['Nutrition_Facts']
nutrition_df = pd.DataFrame(all_nutrition_data)


df_wol = df_wol.reset_index(drop=True)

# glue the new columns onto the right side of original DataFrame
df_wol = pd.concat([df_wol, nutrition_df], axis=1)

print("Final shape:", df_wol.shape)
display(df_wol.head())
# Out:
# original shape: (1414, 5)
# new shape: (1266, 5)
# Final shape: (1266, 12)
#                   Name                                   Ingredients_List  \
# 0  shallot-vinaigrette  ['1  large shallot (minced)', '2 tablespoons h...
# 1          sesame-tofu  ['2 blocks firm or extra firm tofu (anywhere f...
# 2  pork-belly-char-siu  ['2 pounds boneless skinless pork belly (if tr...
# 3      red-bean-zongzi  ['2 pounds sweet rice (also known as sticky ri...
# 4     stir-fry-spinach  ['1 pound spinach (preferably Taiwanese spinac...
#
#                                    Ingredients_Names  \
# 0  ['large shallot', 'hot water', 'white wine vin...
# 1  ['firm or extra firm tofu', 'cornstarch', 'un-...
# 2  ['boneless skinless pork belly', 'granulated s...
# 3  ['sweet rice', 'lye water', 'neutral oil', 'dr...
# 4  ['spinach', 'neutral oil', 'garlic', 'Salt to ...
#
#                                            Procedure  \
# 0  ['In a measuring cup, add the shallots and hot...
# 1  ['Drain each block of tofu. Using your hands, ...
# 2  ['If you have a larger piece of pork belly, cu...
# 3  ['In a large, fine mesh strainer, rinse the sw...
# 4  ['Wash spinach clean by soaking a few times an...
#
#                                      Nutrition_Facts  Calories  Carbohydrates  \
# 0  ['Serving: 6servings', 'Calories: 173kcal (9%)...     173.0            3.0
# 1  ['Serving: 6servings', 'Calories: 358kcal (18%...     358.0           29.0
# 2  ['Serving: 6servings', 'Calories: 682kcal (34%...     682.0           11.0
# 3  ['Serving: 12servings', 'Calories: 344kcal (17...     344.0           72.0
# 4  ['Serving: 4servings', 'Calories: 130kcal (7%)...     130.0            5.0
#
#    Protein   Fat  Saturated Fat  Sodium  Sugar
# 0      0.3  18.0            2.0   0.408    2.0
# 1     15.0  20.0            2.0   0.592    9.0
# 2     15.0  81.0           29.0   0.785   10.0
# 3      8.0   2.0            0.2   0.006    0.0
# 4      3.0  12.0            1.0   0.235    0.5

# %% [markdown]
# ##Omnivore's Cookbook cleaning
# We are looking to
# - remove duplicates
# - parse and expand nutritional info into individual columns

# %%
df_oc = pd.read_csv('omnivores_cookbook_recipes.csv')

print("original shape:", df_oc.shape)


df_oc = df_oc[~(df_oc == "[]").any(axis=1)]

print("new shape:", df_oc.shape)
display(df_oc)

all_nutrition_data = []
for nutrition_string in df_oc['Nutrition_Facts']:

  nutrition_list = ast.literal_eval(nutrition_string)[1:]

  #print(nutrition_list)

  temp_dict = {col: 0 for col in nutrition_columns}
  for nutrient_profile in nutrition_list:


      if ':' not in nutrient_profile:
          continue

      name, value_str = nutrient_profile.split(':', 1)
      nutrient_name = name.strip()

      if nutrient_name in valid_nutrients:
          num = ""
          suffix = ""

          for char in value_str:
              if char.isdigit() or char == '.':
                  num += char
              elif char == '(' or char == '-':
                  break
              else:
                  suffix += char

          if num: # ensure we actually found a number
              temp_dict[nutrient_name] += float(num) * suffix_to_value[suffix.strip()]

  all_nutrition_data.append(temp_dict)

nutrition_df = pd.DataFrame(all_nutrition_data)


df_oc = df_oc.reset_index(drop=True)

# glue the new columns onto the right side of original DataFrame
df_oc = pd.concat([df_oc, nutrition_df], axis=1)

print("Final shape:", df_oc.shape)

display(df_oc.head())
# Out:
# original shape: (684, 5)
# new shape: (637, 5)
#                                 Name  \
# 0                    thai-fish-cakes
# 1                       budae-jjigae
# 2                    drunken-chicken
# 3                    matcha-tiramisu
# 4          clams-in-black-bean-sauce
# ..                               ...
# 674       how-to-make-red-bean-paste
# 675              baked-seafood-pasta
# 677     beef-burger-and-kimchi-pizza
# 678  moms-best-beef-stew-with-tendon
# 681      creamy-chicken-potato-salad
#
#                                       Ingredients_List  \
# 0    ['1 pound white fish fillet , cut into 1-inch ...
# 1    ['1 tablespoon peanut oil (or vegetable oil)',...
# 2    ['2 bone-in skin-on chicken leg quarters (incl...
# 3    ['2 tablespoons ceremonial grade matcha and ex...
# 4    ['2 lbs manila clams', 'Salt , for soaking the...
# ..                                                 ...
# 674  ['300 grams (10 ounces) azuki beans', '200 to ...
# 675  ['2 teaspoons white rum', '200 grams (7 ounces...
# 677  ['1 12 ” (30 cm) thin pizza crusts (or pizza d...
# 678  ['2.4 kilograms (5 pounds) beef plate , cut in...
# 681  ['1 lb (450 g) red potatoes (*Footnote 1)', '1...
#
#                                      Ingredients_Names  \
# 0    ['white fish fillet', 'red curry paste', 'larg...
# 1    ['peanut oil', 'ground beef', 'green onions', ...
# 2    ['bone-in skin-on chicken leg quarters', 'salt...
# 3    ['ceremonial grade matcha', 'very hot water', ...
# 4    ['manila clams', 'Salt', 'vegetable oil', 'Sha...
# ..                                                 ...
# 674              ['azuki beans', 'rock sugar', 'salt']
# 675  ['white rum', 'shrimp', 'squid', 'sea salt', '...
# 677  ['thin pizza crusts', 'sesame oil', 'minced ki...
# 678  ['beef plate', 'beef tendon', 'Shaoxing wine',...
# 681  ['red potatoes', 'plus 1/2 teaspoon salt', 'bo...
#
#                                              Procedure  \
# 0    ['Fish cake:', 'Combine the fish, curry paste,...
# 1    ['Heat oil in a 4-quart dutch oven (or heavy p...
# 2    ['Combine the salt and Sichuan peppercorns in ...
# 3    ['To make the matcha soak: Sift matcha into a ...
# 4    ['Place the clams in a large bowl. Add 8 cups ...
# ..                                                 ...
# 674  ['Combine red beans and 3 cups of water in pre...
# 675  ['In a small bowl, add the shrimp, 1 teaspoon ...
# 677  ['Heat the sesame oil in a small saucepan over...
# 678  ['Place beef tendon in a pressure cooker and a...
# 681  ['Prepare a steamer by adding water to the pot...
#
#                                        Nutrition_Facts
# 0    ['Serving: 1of the 6 servings', 'Calories: 308...
# 1    ['Serving: 4servings', 'Calories: 522kcal', 'C...
# 2    ['Serving: 1serving', 'Calories: 99kcal', 'Car...
# 3    ['Serving: 1serving', 'Calories: 224kcal', 'Ca...
# 4    ['Serving: 1serving', 'Calories: 318kcal', 'Ca...
# ..                                                 ...
# 674  ['Serving: 42g', 'Calories: 147kcal', 'Carbohy...
# 675  ['Serving: 423g', 'Calories: 790kcal', 'Carboh...
# 677  ['Serving: 1serving', 'Calories: 350kcal', 'Ca...
# 678  ['Serving: 169g', 'Calories: 299kcal', 'Carboh...
# 681  ['Serving: 1serving', 'Calories: 295kcal', 'Ca...
#
# [637 rows x 5 columns]
# Final shape: (637, 12)
#                         Name  \
# 0            thai-fish-cakes
# 1               budae-jjigae
# 2            drunken-chicken
# 3            matcha-tiramisu
# 4  clams-in-black-bean-sauce
#
#                                     Ingredients_List  \
# 0  ['1 pound white fish fillet , cut into 1-inch ...
# 1  ['1 tablespoon peanut oil (or vegetable oil)',...
# 2  ['2 bone-in skin-on chicken leg quarters (incl...
# 3  ['2 tablespoons ceremonial grade matcha and ex...
# 4  ['2 lbs manila clams', 'Salt , for soaking the...
#
#                                    Ingredients_Names  \
# 0  ['white fish fillet', 'red curry paste', 'larg...
# 1  ['peanut oil', 'ground beef', 'green onions', ...
# 2  ['bone-in skin-on chicken leg quarters', 'salt...
# 3  ['ceremonial grade matcha', 'very hot water', ...
# 4  ['manila clams', 'Salt', 'vegetable oil', 'Sha...
#
#                                            Procedure  \
# 0  ['Fish cake:', 'Combine the fish, curry paste,...
# 1  ['Heat oil in a 4-quart dutch oven (or heavy p...
# 2  ['Combine the salt and Sichuan peppercorns in ...
# 3  ['To make the matcha soak: Sift matcha into a ...
# 4  ['Place the clams in a large bowl. Add 8 cups ...
#
#                                      Nutrition_Facts  Calories  Carbohydrates  \
# 0  ['Serving: 1of the 6 servings', 'Calories: 308...     308.0           21.8
# 1  ['Serving: 4servings', 'Calories: 522kcal', 'C...     522.0           26.6
# 2  ['Serving: 1serving', 'Calories: 99kcal', 'Car...      99.0            3.0
# 3  ['Serving: 1serving', 'Calories: 224kcal', 'Ca...     224.0           25.5
# 4  ['Serving: 1serving', 'Calories: 318kcal', 'Ca...     318.0           43.1
#
#    Protein   Fat  Saturated Fat  Sodium  Sugar
# 0     16.3  16.5            3.9   1.053   10.9
# 1     39.1  29.1            8.3   1.353   10.1
# 2      9.9   5.1            1.4   0.270    2.0
# 3      7.0  10.8            5.8   0.135   12.6
# 4      3.9  15.0            2.9   2.364   17.2

# %% [markdown]
# ##Combine the two partially cleaned datasets
# Then use .describe() to use identify extreme outliers among other things

# %%
df_final = pd.concat([df_oc, df_wol], axis=0, ignore_index=True)
display(df_final.sample(3))
df_final.describe()
# Out:
#                                 Name  \
# 351                  ma-yi-shang-shu
# 333   bok-choy-and-mushroom-stir-fry
# 1235               hawthorn-iced-tea
#
#                                        Ingredients_List  \
# 351   ['4 oz. (110 g) dried mung bean vermicelli noo...
# 333   ['2 tablespoons water', '2 tablespoons soy sau...
# 1235  ['2 1/2 ounces dried Chinese Hawthorn berries ...
#
#                                       Ingredients_Names  \
# 351   ['dried mung bean vermicelli noodles', 'peanut...
# 333   ['water', 'soy sauce', 'vegetarian oyster sauc...
# 1235  ['dried Chinese Hawthorn berries', 'water', 's...
#
#                                               Procedure  \
# 351   ['Place the vermicelli noodles in a big bowl a...
# 333   ['Mix the sauce ingredients in a small bowl an...
# 1235  ['Add the dried hawthorn and water to a medium...
#
#                                         Nutrition_Facts  Calories  \
# 351   ['Serving: 1serving', 'Calories: 273kcal', 'Ca...     273.0
# 333   ['Serving: 1serving', 'Calories: 151kcal', 'Ca...     151.0
# 1235  ['Serving: 6servings', 'Calories: 32kcal (2%)'...      32.0
#
#       Carbohydrates  Protein  Fat  Saturated Fat  Sodium  Sugar
# 351            35.0     13.7  8.0            1.6   0.471    2.4
# 333            12.8      5.4  9.5            1.6   0.561    4.7
# 1235            8.0      0.0  0.0            0.0   0.013    8.0
#           Calories  Carbohydrates      Protein          Fat  Saturated Fat  \
# count  1903.000000    1903.000000  1903.000000  1903.000000    1903.000000
# mean    307.583085      25.589080    16.340026    15.863537       5.050382
# std     170.962878      21.771941    14.740488    12.217959       5.694472
# min       0.000000       0.000000     0.000000     0.000000       0.000000
# 25%     186.000000       9.000000     6.000000     8.000000       1.200000
# 50%     288.000000      19.000000    14.000000    13.600000       3.000000
# 75%     408.000000      39.000000    23.950000    21.000000       7.000000
# max    1338.000000     204.000000   315.000000   103.000000      82.000000
#
#             Sodium        Sugar
# count  1903.000000  1903.000000
# mean      0.582260     5.955302
# std       0.434239     7.036031
# min       0.000000     0.000000
# 25%       0.298000     2.000000
# 50%       0.540000     3.800000
# 75%       0.818000     7.500000
# max       8.110000    75.000000

# %% [markdown]
# ##Spot extreme outliers and adjust them

# %%
display(df_final[df_final['Protein'] == 315]) #zucchini stir fry is more like 3.15 instead of 315

df_final.loc[285, 'Protein'] = 3.15
df_final.loc[285, 'Nutrition_Facts'] = df_final.loc[285, 'Nutrition_Facts'].replace('315', '3.15')

display(df_final.loc[285])

display(df_final[df_final['Carbohydrates'] == 204])  #recipe didn't scale to 1 serving, #153

df_final.loc[153, 'Carbohydrates'] = 51
df_final.loc[153, 'Nutrition_Facts'] = df_final.loc[153, 'Nutrition_Facts'].replace('204', '51')

display(df_final.loc[153])


display(df_final[df_final['Sodium'] == 8.11]) #recipe didn't scale to 1 serving, #953
df_final.loc[953, 'Sodium'] = 2.03
df_final.loc[953, 'Nutrition_Facts'] = df_final.loc[953, 'Nutrition_Facts'].replace('8.11', '2.03')
display(df_final.loc[953])

display(df_final[df_final['Sugar'] == 75]) #recipe didn't scale to 1 serving #1530
df_final.loc[1530, 'Carbohydrates'] = 3.75
df_final.loc[1530, 'Nutrition_Facts'] = df_final.loc[1530, 'Nutrition_Facts'].replace('75', '3.75')
display(df_final.loc[1530])
# Out:
#                   Name                                   Ingredients_List  \
# 285  zucchini-stir-fry  ['1 lb zucchini', '1 teaspoon salt (Optional)'...
#
#                                      Ingredients_Names  \
# 285  ['zucchini', 'salt', 'peanut oil', 'dried chil...
#
#                                              Procedure  \
# 285  ['Remove the tough ends from the zucchini. Hal...
#
#                                        Nutrition_Facts  Calories  \
# 285  ['Serving: 1serving', 'Calories: 53kcal', 'Car...      53.0
#
#      Carbohydrates  Protein  Fat  Saturated Fat  Sodium  Sugar
# 285            4.9    315.0  3.6            0.6   0.087    2.0
# Name                                                 zucchini-stir-fry
# Ingredients_List     ['1 lb zucchini', '1 teaspoon salt (Optional)'...
# Ingredients_Names    ['zucchini', 'salt', 'peanut oil', 'dried chil...
# Procedure            ['Remove the tough ends from the zucchini. Hal...
# Nutrition_Facts      ['Serving: 1serving', 'Calories: 53kcal', 'Car...
# Calories                                                          53.0
# Carbohydrates                                                      4.9
# Protein                                                           3.15
# Fat                                                                3.6
# Saturated Fat                                                      0.6
# Sodium                                                           0.087
# Sugar                                                              2.0
# Name: 285, dtype: object
#                 Name                                   Ingredients_List  \
# 153  spam-fried-rice  ['1 tablespoon Shaoxing wine (or chicken broth...
#
#                                      Ingredients_Names  \
# 153  ['Shaoxing wine', 'soy sauce', 'oyster sauce',...
#
#                                              Procedure  \
# 153  ['Mix the sauce ingredients together in a smal...
#
#                                        Nutrition_Facts  Calories  \
# 153  ['Serving: 1serving', 'Calories: 526kcal', 'Ca...     526.0
#
#      Carbohydrates  Protein   Fat  Saturated Fat  Sodium  Sugar
# 153          204.0     15.9  22.2            6.0    0.63    3.7
# Name                                                   spam-fried-rice
# Ingredients_List     ['1 tablespoon Shaoxing wine (or chicken broth...
# Ingredients_Names    ['Shaoxing wine', 'soy sauce', 'oyster sauce',...
# Procedure            ['Mix the sauce ingredients together in a smal...
# Nutrition_Facts      ['Serving: 1serving', 'Calories: 526kcal', 'Ca...
# Calories                                                         526.0
# Carbohydrates                                                     51.0
# Protein                                                           15.9
# Fat                                                               22.2
# Saturated Fat                                                      6.0
# Sodium                                                            0.63
# Sugar                                                              3.7
# Name: 153, dtype: object
#                                   Name  \
# 953  spicy-stir-fried-thai-basil-clams
#
#                                       Ingredients_List  \
# 953  ['3 pounds littleneck or cherrystone clams (ab...
#
#                                      Ingredients_Names  \
# 953  ['littleneck or cherrystone clams', 'cold wate...
#
#                                              Procedure  \
# 953  ['To purge the clams of sand and grit, fill a ...
#
#                                        Nutrition_Facts  Calories  \
# 953  ['Serving: 4servings', 'Calories: 132kcal (7%)...     132.0
#
#      Carbohydrates  Protein  Fat  Saturated Fat  Sodium  Sugar
# 953            6.0      8.0  8.0            1.0    8.11    0.3
# Name                                 spicy-stir-fried-thai-basil-clams
# Ingredients_List     ['3 pounds littleneck or cherrystone clams (ab...
# Ingredients_Names    ['littleneck or cherrystone clams', 'cold wate...
# Procedure            ['To purge the clams of sand and grit, fill a ...
# Nutrition_Facts      ['Serving: 4servings', 'Calories: 132kcal (7%)...
# Calories                                                         132.0
# Carbohydrates                                                      6.0
# Protein                                                            8.0
# Fat                                                                8.0
# Saturated Fat                                                      1.0
# Sodium                                                            2.03
# Sugar                                                              0.3
# Name: 953, dtype: object
#                   Name                                   Ingredients_List  \
# 1530  pumpkin-cupcakes  ['2 cups all-purpose flour', '1 teaspoon bakin...
#
#                                       Ingredients_Names  \
# 1530  ['all-purpose flour', 'baking soda', 'baking p...
#
#                                               Procedure  \
# 1530  ['In a medium bowl, combine the flour, baking ...
#
#                                         Nutrition_Facts  Calories  \
# 1530  ['Serving: 20servings', 'Calories: 567kcal (28...     567.0
#
#       Carbohydrates  Protein   Fat  Saturated Fat  Sodium  Sugar
# 1530           88.0      3.0  24.0           14.0   0.196   75.0
# Name                                                  pumpkin-cupcakes
# Ingredients_List     ['2 cups all-purpose flour', '1 teaspoon bakin...
# Ingredients_Names    ['all-purpose flour', 'baking soda', 'baking p...
# Procedure            ['In a medium bowl, combine the flour, baking ...
# Nutrition_Facts      ['Serving: 20servings', 'Calories: 567kcal (28...
# Calories                                                         567.0
# Carbohydrates                                                     3.75
# Protein                                                            3.0
# Fat                                                               24.0
# Saturated Fat                                                     14.0
# Sodium                                                           0.196
# Sugar                                                             75.0
# Name: 1530, dtype: object

# %% [markdown]
# ##Visualize Data
# Looking at the distribution allows us to apply the correct normalization method

# %%
plt.figure()
for nutrient in nutrition_columns:
  plt.hist(df_final[nutrient], bins = 30, color = 'skyblue')
  plt.xlabel(nutrient)
  plt.ylabel('frequency')
  plt.show()

# %% [markdown]
# ##Normalize the data
# Seems like a power law distribution, but there are discrepancies. To safely handle the tails, we use power transformations

# %%
pt = PowerTransformer(method='yeo-johnson')


df_final[nutrition_columns] = pt.fit_transform(df_final[nutrition_columns])


display(df_final[nutrition_columns].describe())
# Out:
#            Calories  Carbohydrates       Protein           Fat  Saturated Fat  \
# count  1.903000e+03   1.903000e+03  1.903000e+03  1.903000e+03   1.903000e+03
# mean   2.389634e-16  -9.707888e-17  1.792226e-16  1.493521e-17  -1.493521e-16
# std    1.000263e+00   1.000263e+00  1.000263e+00  1.000263e+00   1.000263e+00
# min   -2.826850e+00  -2.405412e+00 -2.236308e+00 -2.328329e+00  -2.018212e+00
# 25%   -6.369755e-01  -7.197612e-01 -7.375963e-01 -5.579537e-01  -8.640113e-01
# 50%    1.408581e-02  -7.856125e-03  1.080676e-01  3.947761e-02  -6.421438e-02
# 75%    6.629874e-01   8.290181e-01  7.778754e-01  6.272423e-01   7.887228e-01
# max    4.156938e+00   3.256237e+00  3.420543e+00  3.751676e+00   3.161970e+00
#
#              Sodium         Sugar
# count  1.903000e+03  1.903000e+03
# mean  -2.352296e-16 -5.227324e-17
# std    1.000263e+00  1.000263e+00
# min   -1.869801e+00 -2.159441e+00
# 25%   -6.707774e-01 -5.587072e-01
# 50%    6.004581e-02  4.528671e-02
# 75%    7.304682e-01  7.214374e-01
# max    3.279063e+00  2.812799e+00
