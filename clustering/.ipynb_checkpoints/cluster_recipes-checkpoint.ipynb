# %% [markdown]
# <a href="https://colab.research.google.com/github/warrensuca/chinese-recipe-api/blob/main/clustering/cluster_recipes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import PowerTransformer
import matplotlib.pyplot as plt
print('setup complete')
# Out:
# setup complete

# %%
df_recipes = pd.read_csv('cleaned_recipes.csv')
nutrition_features = ['Calories', 'Carbohydrates', 'Protein', 'Fat', 'Saturated Fat', 'Sodium', 'Sugar']

# %% [markdown]
# #Clustering

# %% [markdown]
# ##Elbow Method
# Find the optimal K

# %%
inertia = []
k_range = range(1, 10)

for k in k_range:
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=0, n_init='auto')
    kmeans.fit(df_recipes[nutrition_features])
    inertia.append(kmeans.inertia_)

# Plot the Elbow curve
plt.plot(k_range, inertia, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ##Cluster recipes and interpret centroids

# %%
df_recipes = pd.read_csv('cleaned_raw_recipes.csv')

kmeans = KMeans(n_clusters=5, random_state=0)

pt = PowerTransformer(method='yeo-johnson')


scaled_features = pt.fit_transform(df_recipes[nutrition_features])

#create non-scaled and scaled columns
for index, name in enumerate(nutrition_features):
  df_recipes[f'Scaled_{name}'] = scaled_features[:, index]
df_recipes['Cluster'] = kmeans.fit_predict(scaled_features)


scaled_centers = kmeans.cluster_centers_


real_world_centers = pt.inverse_transform(scaled_centers)


cluster_profiles = pd.DataFrame(real_world_centers, columns=nutrition_features)
cluster_profiles.index = [f"Cluster {i}" for i in range(5)]


display(cluster_profiles.round(1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
#            Calories  Carbohydrates  Protein   Fat  Saturated Fat  Sodium  \
# Cluster 0     103.9            9.4      3.7   4.1            0.9     0.3
# Cluster 1     540.1           34.7     23.9  30.4            9.7     0.8
# Cluster 2     269.1           32.7      5.0  11.6            4.2     0.2
# Cluster 3     331.0           32.7     18.3  11.8            2.1     0.8
# Cluster 4     277.8            7.8     19.0  16.7            4.4     0.6
#
#            Sugar
# Cluster 0    1.7
# Cluster 1    5.2
# Cluster 2   13.3
# Cluster 3    4.7
# Cluster 4    2.0

# %% [markdown]
# ##Seem to be distinct archetypes
# - sides
# - protein/meat heavy mains
# - sweets
# - balanced meals
# - keto friendly

# %%
cluster_names = {
    0: "Light Sides & Soups",
    1: "Rich Meat Mains",
    2: "Desserts & Sweets",
    3: "Balanced Carb-Mains",
    4: "Low-Carb Proteins"
}


df_recipes['Cluster_Name'] = df_recipes['Cluster'].map(cluster_names)

df_recipes.head()
# Out:
#                         Name  \
# 0            thai-fish-cakes
# 1               budae-jjigae
# 2            drunken-chicken
# 3            matcha-tiramisu
# 4  clams-in-black-bean-sauce
#
#                                     Ingredients_List  \
# 0  ['1 pound white fish fillet , cut into 1-inch ...
# 1  ['1 tablespoon peanut oil (or vegetable oil)',...
# 2  ['2 bone-in skin-on chicken leg quarters (incl...
# 3  ['2 tablespoons ceremonial grade matcha and ex...
# 4  ['2 lbs manila clams', 'Salt , for soaking the...
#
#                                    Ingredients_Names  \
# 0  ['white fish fillet', 'red curry paste', 'larg...
# 1  ['peanut oil', 'ground beef', 'green onions', ...
# 2  ['bone-in skin-on chicken leg quarters', 'salt...
# 3  ['ceremonial grade matcha', 'very hot water', ...
# 4  ['manila clams', 'Salt', 'vegetable oil', 'Sha...
#
#                                            Procedure  \
# 0  ['Fish cake:', 'Combine the fish, curry paste,...
# 1  ['Heat oil in a 4-quart dutch oven (or heavy p...
# 2  ['Combine the salt and Sichuan peppercorns in ...
# 3  ['To make the matcha soak: Sift matcha into a ...
# 4  ['Place the clams in a large bowl. Add 8 cups ...
#
#                                      Nutrition_Facts  Calories  Carbohydrates  \
# 0  ['Serving: 1of the 6 servings', 'Calories: 308...     308.0           21.8
# 1  ['Serving: 4servings', 'Calories: 522kcal', 'C...     522.0           26.6
# 2  ['Serving: 1serving', 'Calories: 99kcal', 'Car...      99.0            3.0
# 3  ['Serving: 1serving', 'Calories: 224kcal', 'Ca...     224.0           25.5
# 4  ['Serving: 1serving', 'Calories: 318kcal', 'Ca...     318.0           43.1
#
#    Protein   Fat  Saturated Fat  ...  Sugar  Scaled_Calories  \
# 0     16.3  16.5            3.9  ...   10.9         0.129310
# 1     39.1  29.1            8.3  ...   10.1         1.206753
# 2      9.9   5.1            1.4  ...    2.0        -1.330232
# 3      7.0  10.8            5.8  ...   12.6        -0.379936
# 4      3.9  15.0            2.9  ...   17.2         0.185721
#
#    Scaled_Carbohydrates  Scaled_Protein  Scaled_Fat  Scaled_Saturated Fat  \
# 0              0.140144        0.287186    0.289290              0.193493
# 1              0.364220        1.499514    1.134243              0.964090
# 2             -1.500381       -0.268062   -0.972870             -0.743717
# 3              0.315679       -0.602039   -0.235396              0.595562
# 4              0.958079       -1.076017    0.163840             -0.096843
#
#    Scaled_Sodium  Scaled_Sugar  Cluster         Cluster_Name
# 0       1.198400      1.091783        3  Balanced Carb-Mains
# 1       1.701154      1.016798        1      Rich Meat Mains
# 2      -0.767056     -0.558707        0  Light Sides & Soups
# 3      -1.274549      1.233359        2    Desserts & Sweets
# 4       2.914547      1.532037        3  Balanced Carb-Mains
#
# [5 rows x 21 columns]

# %% [markdown]
# ##Assess results
# Use cluster cardinality, cluster magnitude, then graph against each other to interpret results

# %%
#x axis is categories, y axis is # of examples under this cluster
names = list(cluster_names.keys())
points_in_cluster = df_recipes['Cluster_Name'].value_counts()


plt.bar(names, points_in_cluster, color='skyblue', edgecolor='black', width=0.6)


plt.title('Cardinality')
plt.xlabel('Cluster Number from 0 to 4')
plt.ylabel('Points in Cluster')


plt.show()

# %%
output_file = "clustered_recipes.csv"

df_recipes.to_csv(
    output_file,
    index=False,
    encoding="utf-8"
)

print(f"Output file: {output_file}")
# Out:
# Output file: clustered_recipes.csv
